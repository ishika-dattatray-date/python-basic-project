# %% [markdown]
# <a href="https://colab.research.google.com/github/ishika-dattatray-date/python-basic-project/blob/main/Assignment_19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a17011cc-11df-4e9b-856d-4363e7ab271d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a17011cc-11df-4e9b-856d-4363e7ab271d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())

# %%
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df = df.drop(columns=['Cabin'])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (891, 11)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Fare'].min()
# Out:
# 0.0

# %%
df['Fare'].max()
# Out:
# 512.3292

# %%
df['Fare'].mean()
# Out:
# np.float64(32.204207968574636)

# %%
df['Fare'].median()
# Out:
# 14.4542

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Age'], bins=20)
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Fare'], bins=20)
plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['SibSp'], bins=10)
plt.title("Siblings/Spouses Distribution")
plt.xlabel("SibSp")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['Parch'], bins=10)
plt.title("Parents/Children Distribution")
plt.xlabel("Parch")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.hist(df['PassengerId'], bins=20)
plt.title("Passenger ID Distribution")
plt.xlabel("Passenger ID")
plt.ylabel("Frequency")
plt.show()

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Embarked'], dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Sex', data=df)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Embarked', data=df)
plt.title("Embarked Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Pclass', data=df)
plt.title("Passenger Class Distribution")
plt.show()

# %%
correlation = df.select_dtypes(include=['number']).corr()

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    correlation,
    annot=True,
    cmap='coolwarm',
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.show()

# %%
correlation['Fare'].sort_values(ascending=False)
# Out:
# Fare           1.000000
# Survived       0.257307
# Parch          0.216225
# SibSp          0.159651
# Age            0.096688
# PassengerId    0.012658
# Pclass        -0.549500
# Name: Fare, dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
X = df.drop('Fare', axis=1)
X.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket Embarked
# 0      0         A/5 21171        S
# 1      0          PC 17599        C
# 2      0  STON/O2. 3101282        S
# 3      0            113803        S
# 4      0            373450        S

# %%
y = df['Fare']
y.head()
# Out:
# 0     7.2500
# 1    71.2833
# 2     7.9250
# 3    53.1000
# 4     8.0500
# Name: Fare, dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Embarked'], dtype='object')

# %%
df[['Sex', 'Embarked']].head()
# Out:
#       Sex Embarked
# 0    male        S
# 1  female        C
# 2  female        S
# 3  female        S
# 4    male        S

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
df_encoded.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  \
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500
#
#    Name_Abbott, Mr. Rossmore Edward  Name_Abbott, Mrs. Stanton (Rosa Hunt)  \
# 0                             False                                  False
# 1                             False                                  False
# 2                             False                                  False
# 3                             False                                  False
# 4                             False                                  False
#
#    Name_Abelson, Mr. Samuel  ...  Ticket_W./C. 14258  Ticket_W./C. 14263  \
# ...

# %%
df_encoded.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Name_Abbott, Mr. Rossmore Edward',
#        'Name_Abbott, Mrs. Stanton (Rosa Hunt)', 'Name_Abelson, Mr. Samuel',
#        ...
#        'Ticket_W./C. 14258', 'Ticket_W./C. 14263', 'Ticket_W./C. 6607',
#        'Ticket_W./C. 6608', 'Ticket_W./C. 6609', 'Ticket_W.E.P. 5734',
#        'Ticket_W/C 14208', 'Ticket_WE/P 5735', 'Embarked_Q', 'Embarked_S'],
#       dtype='object', length=1580)

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop('Fare', axis=1)

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X)

# %%
scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

# %%
scaled_df.head()
# Out:
#    PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# 0    -1.730108 -0.789272  0.827377 -0.565736  0.432793 -0.473674
# 1    -1.726220  1.266990 -1.566107  0.663861  0.432793 -0.473674
# 2    -1.722332  1.266990  0.827377 -0.258337 -0.474545 -0.473674
# 3    -1.718444  1.266990 -1.566107  0.433312  0.432793 -0.473674
# 4    -1.714556 -0.789272  0.827377  0.433312 -0.474545 -0.473674
#
#    Name_Abbott, Mr. Rossmore Edward  Name_Abbott, Mrs. Stanton (Rosa Hunt)  \
# 0                          -0.03352                               -0.03352
# 1                          -0.03352                               -0.03352
# 2                          -0.03352                               -0.03352
# 3                          -0.03352                               -0.03352
# 4                          -0.03352                               -0.03352
#
#    Name_Abelson, Mr. Samuel  Name_Abelson, Mrs. Samuel (Hannah Wizosky)  ...  \
# ...
